# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df


def my_neo4j_page_rank(max_iterations=20, damping_factor=0.85):
    "given a from station and to station, run and print the shortest path"
    
    query = "CALL gds.graph.drop('ds_graph', false)"
    session.run(query)

    query = "CALL gds.graph.project('ds_graph', 'Station', 'LINK', {relationshipProperties: 'weight'})"
    session.run(query)

    query = """

    CALL gds.pageRank.stream('ds_graph',
                         { maxIterations: $max_iterations,
                           dampingFactor: $damping_factor}
                         )
    YIELD nodeId, score
    RETURN gds.util.asNode(nodeId).name AS name, score as page_rank
    ORDER BY page_rank DESC, name ASC

    """

    return my_neo4j_run_query_pandas(query, max_iterations=max_iterations, damping_factor=damping_factor)

# %%
df = my_neo4j_page_rank()

df_drop = df[~df['name'].str.contains('depart|arrive', regex=True)]
df_drop
# Out:
#                  name  page_rank
# 0       blue Coliseum   0.689786
# 1     orange Coliseum   0.689174
# 2      green Coliseum   0.688970
# 3       blue Bay Fair   0.675695
# 4    yellow MacArthur   0.675481
# ..                ...        ...
# 122   orange Richmond   0.477049
# 123      red Richmond   0.477049
# 124    yellow Antioch   0.463809
# 127       blue Dublin   0.457066
# 147          gray OAK   0.386077
#
# [114 rows x 2 columns]

# %%
df_drop['name'] = df_drop['name'].apply(lambda line: ' '.join(line.split()[1:]))

df_drop
# Out:
# /tmp/ipykernel_133/395613043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drop['name'] = df_drop['name'].apply(lambda line: ' '.join(line.split()[1:]))
#           name  page_rank
# 0     Coliseum   0.689786
# 1     Coliseum   0.689174
# 2     Coliseum   0.688970
# 3     Bay Fair   0.675695
# 4    MacArthur   0.675481
# ..         ...        ...
# 122   Richmond   0.477049
# 123   Richmond   0.477049
# 124    Antioch   0.463809
# 127     Dublin   0.457066
# 147        OAK   0.386077
#
# [114 rows x 2 columns]

# %%
final_df = df_drop.groupby('name')['page_rank'].mean().reset_index().sort_values(by="page_rank", ascending=False)

final_df
# Out:
#                     name  page_rank
# 11              Coliseum   0.676688
# 35      Pittsburg Center   0.657564
# 26             MacArthur   0.652098
# 7               Bay Fair   0.651456
# 34             Pittsburg   0.645698
# 49          West Oakland   0.644398
# 31         North Concord   0.641970
# 13               Concord   0.640679
# 36         Pleasant Hill   0.639852
# 46          Walnut Creek   0.638228
# 6            Balboa Park   0.635737
# 48           West Dublin   0.633782
# 24             Lafayette   0.633328
# 19           Embarcadero   0.628583
# 22             Glen Park   0.626299
# 29     Montgomery Street   0.624403
# 3    24th Street Mission   0.623803
# 37         Powell Street   0.623307
# 1    16th Street Mission   0.623159
# 10          Civic Center   0.623060
# 33                Orinda   0.617667
# 41             San Bruno   0.617093
# 14             Daly City   0.615695
# 2            19th Street   0.612071
# 42           San Leandro   0.607288
# 28              Milpitas   0.603177
# 18  El Cerrito del Norte   0.603054
# 47          Warm Springs   0.593410
# 17      El Cerrito Plaza   0.593005
# 0            12th Street   0.592356
# 21             Fruitvale   0.590684
# 20               Fremont   0.590169
# 30        North Berkeley   0.588795
# 45            Union City   0.587942
# 25          Lake Merritt   0.587100
# 44   South San Francisco   0.586537
# 15     Downtown Berkeley   0.583265
# 43         South Hayward   0.582948
# 9          Castro Valley   0.571916
# 39             Rockridge   0.567313
# 5                  Ashby   0.567007
# 23               Hayward   0.566689
# 27              Millbrae   0.554540
# 12                 Colma   0.550855
# 40                   SFO   0.498141
# 8              Berryessa   0.477086
# 38              Richmond   0.477049
# 4                Antioch   0.463809
# 16                Dublin   0.457066
# 32                   OAK   0.386077
